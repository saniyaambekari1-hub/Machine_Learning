# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

# %%
data = {"Course Name":["Java","Python","AI/ML","C"],"Hours":[3,2,1,4]}
df =  pd.DataFrame(data)
df
# Out:
#   Course Name  Hours
# 0        Java      3
# 1      Python      2
# 2       AI/ML      1
# 3           C      4

# %%
df.max()
# Out:
# Course Name    Python
# Hours               4
# dtype: object

# %%
df.min()
# Out:
# Course Name    AI/ML
# Hours              1
# dtype: object

# %%
print(np.mean(df["Hours"]))
# Out:
# 2.5

# %%
plt.scatter(df["Course Name"], df["Hours"])
plt.xlabel("Course Name")
plt.ylabel("Hours")
plt.show();
